# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Learning

# %%
#creathing path
path = r"C:\Users\logan\Downloads\CareerFoundry\Instacart Basket Analysis"

# %%
#importing data
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged 4.7.pkl'))

# %%
df = ords_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 16)

# %%
df.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
# 5   1701441      777            16                   1                  7
# 6   1871483      825             3                   2                 14
# 7   1290456      910            12                   3                 10
# 8    369558     1052            10                   1                 20
# 9    589712     1052            15                   1                 12
#
#    days_since_prior_order  add_to_cart_order  reordered    price_range_loc  \
# 0                     3.0                  5          0  Mid-range product
# 1                    20.0                  1          1  Mid-range product
# 2                     6.0                 20          0  Mid-range product
# 3                     NaN                 10          0  Mid-range product
# 4                     9.0                 11          1  Mid-range product
# 5                    26.0                  7          0  Mid-range product
# 6                    30.0                  2          0  Mid-range product
# 7                    30.0                  1          0  Mid-range product
# 8                    19.0                  1          0  Mid-range product
# 9                    15.0                  2          1  Mid-range product
#
#            busiest_day busiest_period_of_day
# 0  Regularly busy days           Most orders
# 1  Regularly busy days        Average orders
# 2         Busiest days        Average orders
# 3      Least busy days           Most orders
# 4      Least busy days        Average orders
# 5         Busiest days        Average orders
# 6  Regularly busy days           Most orders
# 7      Least busy days           Most orders
# 8         Busiest days        Average orders
# 9         Busiest days           Most orders

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.562844
# 2                17.518895
# 3                16.907152
# 4                17.537934
# 5                14.894521
# 6                16.658449
# 7                17.072954
# 8                14.942021
# 9                15.447580
# 10               18.681852
# 11               15.352278
# 12               14.327957
# 13               16.578690
# 14               16.666369
# 15               16.153766
# 16               17.768070
# 17               15.602964
# 18               19.674252
# 19               16.924344
# 20               16.292631
# 21               25.535596

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.562844
# 2     17.518895
# 3     16.907152
# 4     17.537934
# 5     14.894521
# 6     16.658449
# 7     17.072954
# 8     14.942021
# 9     15.447580
# 10    18.681852
# 11    15.352278
# 12    14.327957
# 13    16.578690
# 14    16.666369
# 15    16.153766
# 16    17.768070
# 17    15.602964
# 18    19.674252
# 19    16.924344
# 20    16.292631
# 21    25.535596
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.562844   1  99
# 2                17.518895   1  96
# 3                16.907152   1  99
# 4                17.537934   1  99
# 5                14.894521   1  99
# 6                16.658449   1  99
# 7                17.072954   1  99
# 8                14.942021   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.352278   1  99
# 12               14.327957   1  99
# 13               16.578690   1  99
# 14               16.666369   1  99
# 15               16.153766   1  99
# 16               17.768070   1  99
# 17               15.602964   1  99
# 18               19.674252   1  99
# 19               16.924344   1  99
# 20               16.292631   1  99
# 21               25.535596   1  98

# %%
ords_prods_merged['max_order'] = ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\logan\AppData\Local\Temp\ipykernel_27928\3299225553.py:1: FutureWarning: The provided callable <function amax at 0x000001952EB13920> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merged['max_order'] = ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merged.head(100)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# ..         ...                         ...       ...            ...     ...
# 95           1  Chocolate Sandwich Cookies        61             19     5.8
# 96           1  Chocolate Sandwich Cookies        61             19     5.8
# 97           1  Chocolate Sandwich Cookies        61             19     5.8
# 98           1  Chocolate Sandwich Cookies        61             19     5.8
# 99           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    3139998      138            28                   6                 11
# 1    1977647      138            30                   6                 17
# 2     389851      709             2                   0                 21
# 3     652770      764             1                   3                 13
# 4    1813452      764             3                   4                 17
# ..       ...      ...           ...                 ...                ...
# 95    602103    10831             8                   3                 11
# 96     49629    11119            18                   1                 14
# 97    317888    11186            13                   5                 16
# 98    682486    11243            16                   3                 13
# 99   2861386    11448            10                   2                 15
#
#     days_since_prior_order  add_to_cart_order  reordered    price_range_loc  \
# 0                      3.0                  5          0  Mid-range product
# 1                     20.0                  1          1  Mid-range product
# 2                      6.0                 20          0  Mid-range product
# 3                      NaN                 10          0  Mid-range product
# 4                      9.0                 11          1  Mid-range product
# ..                     ...                ...        ...                ...
# 95                    23.0                  5          0  Mid-range product
# 96                    30.0                  1          0  Mid-range product
# 97                     2.0                  8          0  Mid-range product
# 98                     0.0                  2          0  Mid-range product
# 99                     3.0                  6          0  Mid-range product
#
#             busiest_day busiest_period_of_day  max_order
# 0   Regularly busy days           Most orders         32
# 1   Regularly busy days        Average orders         32
# 2          Busiest days        Average orders          5
# 3       Least busy days           Most orders          3
# 4       Least busy days        Average orders          3
# ..                  ...                   ...        ...
# 95      Least busy days           Most orders         10
# 96         Busiest days           Most orders         23
# 97  Regularly busy days           Most orders         26
# 98      Least busy days           Most orders         43
# 99  Regularly busy days           Most orders         21
#
# [100 rows x 17 columns]

# %%
ords_prods_merged.loc[ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# C:\Users\logan\AppData\Local\Temp\ipykernel_27928\4020493799.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Loyal customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merged.loc[ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merged.loc[(ords_prods_merged['max_order'] <= 40) & (ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merged.loc[ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merged.head(100)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# ..         ...                         ...       ...            ...     ...
# 95           1  Chocolate Sandwich Cookies        61             19     5.8
# 96           1  Chocolate Sandwich Cookies        61             19     5.8
# 97           1  Chocolate Sandwich Cookies        61             19     5.8
# 98           1  Chocolate Sandwich Cookies        61             19     5.8
# 99           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    3139998      138            28                   6                 11
# 1    1977647      138            30                   6                 17
# 2     389851      709             2                   0                 21
# 3     652770      764             1                   3                 13
# 4    1813452      764             3                   4                 17
# ..       ...      ...           ...                 ...                ...
# 95    602103    10831             8                   3                 11
# 96     49629    11119            18                   1                 14
# 97    317888    11186            13                   5                 16
# 98    682486    11243            16                   3                 13
# 99   2861386    11448            10                   2                 15
#
#     days_since_prior_order  add_to_cart_order  reordered    price_range_loc  \
# 0                      3.0                  5          0  Mid-range product
# 1                     20.0                  1          1  Mid-range product
# 2                      6.0                 20          0  Mid-range product
# 3                      NaN                 10          0  Mid-range product
# 4                      9.0                 11          1  Mid-range product
# ..                     ...                ...        ...                ...
# 95                    23.0                  5          0  Mid-range product
# 96                    30.0                  1          0  Mid-range product
# 97                     2.0                  8          0  Mid-range product
# 98                     0.0                  2          0  Mid-range product
# 99                     3.0                  6          0  Mid-range product
#
#             busiest_day busiest_period_of_day  max_order      loyalty_flag
# 0   Regularly busy days           Most orders         32  Regular customer
# 1   Regularly busy days        Average orders         32  Regular customer
# 2          Busiest days        Average orders          5      New customer
# 3       Least busy days           Most orders          3      New customer
# 4       Least busy days        Average orders          3      New customer
# ..                  ...                   ...        ...               ...
# 95      Least busy days           Most orders         10      New customer
# 96         Busiest days           Most orders         23  Regular customer
# 97  Regularly busy days           Most orders         26  Regular customer
# 98      Least busy days           Most orders         43    Loyal customer
# 99  Regularly busy days           Most orders         21  Regular customer
#
# [100 rows x 18 columns]

# %%
ords_prods_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# 20     1540  Regular customer             7
# 21     1540  Regular customer             8
# 22     1540  Regular customer             9
# 23     1540  Regular customer            14
# 24     1540  Regular customer            15
# 25     1540  Regular customer            18
# 26     1540  Regular customer            19
# 27     1540  Regular customer            20
# 28     1540  Regular customer            21
# 29     1540  Regular customer            22
# 30     1540  Regular customer            24
# 31     1540  Regular customer            25
# 32     1540  Regular customer            27
# 33     1540  Regular customer            28
# 34     1598      New customer             1
# 35     1598      New customer             2
# 36     1598      New customer             3
# 37     1647      New customer             1
# 38     1647      New customer             4
# 39     1647      New customer             6
# 40     1647      New customer             8
# 41     1647      New customer             9
# 42     2833      New customer             1
# 43     2850  Regular customer             7
# 44     2857  Regular customer            24
# 45     3010  Regular customer             5
# 46     3029      New customer             1
# 47     3395      New customer             4
# 48     3904      New customer             1
# 49     4006    Loyal customer             2
# 50     4006    Loyal customer             3
# 51     4006    Loyal customer             5
# 52     4006    Loyal customer             9
# 53     4006    Loyal customer            12
# 54     4122  Regular customer            11
# 55     4141      New customer             2
# 56     4343      New customer             1
# 57     4553      New customer             3
# 58     4845  Regular customer             6
# 59     6866      New customer             1

# %%
ords_prods_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32434207       49688      Fresh Foaming Cleanser        73             11
# 32434208       49688      Fresh Foaming Cleanser        73             11
# 32434209       49688      Fresh Foaming Cleanser        73             11
# 32434210       49688      Fresh Foaming Cleanser        73             11
# 32434211       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  orders_day_of_week  \
# 0            5.8   3139998      138            28                   6
# 1            5.8   1977647      138            30                   6
# 2            5.8    389851      709             2                   0
# 3            5.8    652770      764             1                   3
# 4            5.8   1813452      764             3                   4
# ...          ...       ...      ...           ...                 ...
# 32434207    13.5   1788356   200215             2                   0
# 32434208    13.5   3401313   200377             1                   4
# 32434209    13.5    809510   200873             5                   3
# 32434210    13.5   2359893   200873             9                   3
# 32434211    13.5   2385091   205926            11                   1
#
#           order_hour_of_day  days_since_prior_order  add_to_cart_order  \
# 0                        11                     3.0                  5
# 1                        17                    20.0                  1
# 2                        21                     6.0                 20
# 3                        13                     NaN                 10
# 4                        17                     9.0                 11
# ...                     ...                     ...                ...
# 32434207                  9                     5.0                 27
# 32434208                 11                     NaN                  5
# 32434209                  8                    15.0                 12
# 32434210                 15                     5.0                 11
# 32434211                 15                     6.0                 35
#
#           reordered    price_range_loc          busiest_day  \
# 0                 0  Mid-range product  Regularly busy days
# 1                 1  Mid-range product  Regularly busy days
# 2                 0  Mid-range product         Busiest days
# 3                 0  Mid-range product      Least busy days
# 4                 1  Mid-range product      Least busy days
# ...             ...                ...                  ...
# 32434207          0  Mid-range product         Busiest days
# 32434208          0  Mid-range product      Least busy days
# 32434209          0  Mid-range product      Least busy days
# 32434210          1  Mid-range product      Least busy days
# 32434211          0  Mid-range product         Busiest days
#
#          busiest_period_of_day  max_order      loyalty_flag
# 0                  Most orders         32  Regular customer
# 1               Average orders         32  Regular customer
# 2               Average orders          5      New customer
# 3                  Most orders          3      New customer
# 4               Average orders          3      New customer
# ...                        ...        ...               ...
# 32434207           Most orders          6      New customer
# 32434208           Most orders          4      New customer
# 32434209        Average orders         20  Regular customer
# 32434210           Most orders         20  Regular customer
# 32434211           Most orders         11  Regular customer
#
# [32434212 rows x 18 columns]

# %%
ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: count, dtype: int64

# %%
ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged 4.8.pkl'))
