# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Exercise

# %%
#creathing path
path = r"C:\Users\logan\Downloads\CareerFoundry\Instacart Basket Analysis"

# %%
#importing data
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged 4.8.pkl'))

# %%
ords_prods_merge.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# ...

# %%
#finding the mean for the entire dataframe
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457687
# 2                17.277920
# 3                17.179756
# 4                17.811403
# 5                15.213779
# 6                16.439806
# 7                17.225773
# 8                15.340520
# 9                15.895474
# 10               20.197148
# 11               16.170828
# 12               15.887622
# 13               16.583304
# 14               16.757377
# 15               16.165037
# 16               17.663250
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # 3. The means are mostly similar to the subset from the Exercise

# %% [markdown]
# # 4. Done in the exercise, you can see the results in the search above

# %%
#finding average spent by customers
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.388747  1.0  99999.0
# New customer      13.294370  1.0  99999.0
# Regular customer  12.496203  1.0  99999.0

# %% [markdown]
# # That max price doesn't look right, going to do some investigating on it

# %%
#creating subsets to look for high prices
sorted_df = ords_prods_merge.sort_values(by='prices', ascending=False)

# %%
sorted_df.head(100)
# Out:
#           product_id           product_name  aisle_id  department_id   prices  \
# 21814982       33664  2 % Reduced Fat  Milk        84             16  99999.0
# 21814657       33664  2 % Reduced Fat  Milk        84             16  99999.0
# 21814665       33664  2 % Reduced Fat  Milk        84             16  99999.0
# 21814664       33664  2 % Reduced Fat  Milk        84             16  99999.0
# 21814663       33664  2 % Reduced Fat  Milk        84             16  99999.0
# ...              ...                    ...       ...            ...      ...
# 21814721       33664  2 % Reduced Fat  Milk        84             16  99999.0
# 21814720       33664  2 % Reduced Fat  Milk        84             16  99999.0
# 21814719       33664  2 % Reduced Fat  Milk        84             16  99999.0
# 21814717       33664  2 % Reduced Fat  Milk        84             16  99999.0
# 21814728       33664  2 % Reduced Fat  Milk        84             16  99999.0
#
# ...

# %%
milk_products = sorted_df[sorted_df['product_name'].str.contains('milk', case=False, na=False)]

# %%
milk_products.groupby('product_name')

# %%
milk_products.shape
# Out:
# (1917728, 18)

# %%
milk_prices = milk_products.groupby('product_name').agg({'prices' : ['min', 'max']})

# %%
milk_prices.head()
# Out:
#                               prices
#                                  min   max
# product_name
# 0% Fat Free Organic Milk        12.9  12.9
# 0% Milkfat Greek Plain Yogurt    6.3   6.3
# 0% Milkfat Greek Yogurt Honey    2.4   2.4
# 1 % Lowfat Milk                 13.0  13.0
# 1% Chocolate Milk                8.3   8.3

# %%
pricey_milk = milk_products[milk_products['prices'] > 25]

# %%
pricey_milk.shape
# Out:
# (5127, 18)

# %%
pricey_milk_2= pricey_milk.groupby('product_name').agg({'prices' : ['min', 'max']})

# %%
pricey_milk_2.shape
# Out:
# (2, 2)

# %%
pricey_milk_2.head()
# Out:
#                                    prices
#                                       min      max
# product_name
# 2 % Reduced Fat  Milk             99999.0  99999.0
# Lowfat 2% Milkfat Cottage Cheese  14900.0  14900.0

# %%
filtered_products = ords_prods_merge[(ords_prods_merge['product_name'].str.contains('Cottage Cheese', case=False, na=False)) & (ords_prods_merge['prices'] < 25)]

# %%
filtered_products.head(10)
# Out:
#         product_id                                       product_name  \
# 103250         195  Grade A Pasteurized 2% Milkfat Lowfat Cottage ...
# 103251         195  Grade A Pasteurized 2% Milkfat Lowfat Cottage ...
# 103252         195  Grade A Pasteurized 2% Milkfat Lowfat Cottage ...
# 103253         195  Grade A Pasteurized 2% Milkfat Lowfat Cottage ...
# 103254         195  Grade A Pasteurized 2% Milkfat Lowfat Cottage ...
# 103255         195  Grade A Pasteurized 2% Milkfat Lowfat Cottage ...
# 103256         195  Grade A Pasteurized 2% Milkfat Lowfat Cottage ...
# 103257         195  Grade A Pasteurized 2% Milkfat Lowfat Cottage ...
# 103258         195  Grade A Pasteurized 2% Milkfat Lowfat Cottage ...
# 103259         195  Grade A Pasteurized 2% Milkfat Lowfat Cottage ...
#
#         aisle_id  department_id  prices  order_id  user_id  order_number  \
# 103250       108             16     3.3   2186058    16404             5
# ...

# %%
#finding average price of cottage cheese products
filtered_products.agg({'prices' : ['mean', 'min', 'max']})
# Out:
#          prices
# mean   7.542921
# min    1.100000
# max   15.000000

# %%
ords_prods_merge.loc[ords_prods_merge['product_name'] == 'Lowfat 2% Milkfat Cottage Cheese', 'prices'] = 7.5

# %%
whole_milk_rows = ords_prods_merge[ords_prods_merge['product_name'].str.contains('whole milk', case=False, na=False)]

# %%
whole_milk_rows.groupby('product_name').agg({'prices':['mean', 'max', 'min']})
# Out:
#                                                    prices
#                                                      mean   max   min
# product_name
# Baked Scalloped Potatoes With Real Cheddar Chee...    2.0   2.0   2.0
# Blueberry Drinkable Whole Milk Yogurt                 9.7   9.7   9.7
# Blueberry Whole Milk Yogurt Pouch                     6.1   6.1   6.1
# Cheese, Whole Milk Cheese, Cremoso                   11.8  11.8  11.8
# Cotija Whole Milk Cheese                              8.2   8.2   8.2
# ...                                                   ...   ...   ...
# Whole Milk, Vitamin D, Jug                            6.2   6.2   6.2
# Wildberries Organic Probiotic Whole Milk Kefir        3.2   3.2   3.2
# Yo Baby Organic Whole Milk Banana Mango Yogurt        2.3   2.3   2.3
# Yo Toddler Organic Strawberry Banana Whole Milk...    2.5   2.5   2.5
# YoTot Apple Sweet Potato with Fruit & Veggies O...    1.8   1.8   1.8
#
# [116 rows x 3 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['product_name'] == '2 % Reduced Fat  Milk', 'prices'] = 6

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.778386  1.0  25.0
# New customer      7.805556  1.0  25.0
# Regular customer  7.802887  1.0  25.0

# %% [markdown]
# # As you can see, I changed the outlandish prices to something more reasonable for what they are looking at similar products

# %% [markdown]
# # 5. The average price is pretty close to each other, but actually slightly lower for loyal customers

# %%
#creating an average price column
ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\logan\AppData\Local\Temp\ipykernel_5584\2073074866.py:2: FutureWarning: The provided callable <function mean at 0x000002C270CF2AC0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# ...

# %%
#creating "Spending habits" flag
ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'spending_habit'] = 'Low spender'
# Out:
# C:\Users\logan\AppData\Local\Temp\ipykernel_5584\3618674252.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Low spender' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'spending_habit'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['average_price'] >= 10, 'spending_habit'] = 'High spender'

# %%
ords_prods_merge['spending_habit'].value_counts(dropna = False)
# Out:
# spending_habit
# Low spender     32313511
# High spender      120701
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
# ...

# %%
#creating median orders
ords_prods_merge['median_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\logan\AppData\Local\Temp\ipykernel_5584\2418541316.py:2: FutureWarning: The provided callable <function median at 0x000002C270E33A60> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['median_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
# Out:
# C:\Users\logan\AppData\Local\Temp\ipykernel_5584\2105341910.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Non-frequent customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['median_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_orders'] > 10) & (ords_prods_merge['median_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
#checking counts
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        21577409
# Regular customer          7217134
# Non-frequent customer     3639669
# Name: count, dtype: int64

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged 4.82.pkl'))
